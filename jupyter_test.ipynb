# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(0.01740522416934788), np.float64(1.005917787932923))

# %% [markdown]
# This is a test for math equations in Jupyter Notebook. $E = mc^2$. $\displaystyle \sum_{n=1}^{\infty} \frac{1}{n^2} = \frac{\pi^2}{6} $

# %%
# %timeit np.random.randn(10000)
# Out:
# 78.3 μs ± 204 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
import matplotlib.pyplot as plt
plt.hist(data, bins=30)
# Out:
# (array([ 1.,  0.,  2.,  8., 15., 18., 27., 36., 46., 52., 61., 64., 99.,
#         84., 80., 75., 69., 79., 55., 44., 30., 20., 10., 13.,  8.,  2.,
#          0.,  1.,  0.,  1.]),
#  array([-3.05625094, -2.8347761 , -2.61330126, -2.39182642, -2.17035157,
#         -1.94887673, -1.72740189, -1.50592705, -1.28445221, -1.06297737,
#         -0.84150253, -0.62002768, -0.39855284, -0.177078  ,  0.04439684,
#          0.26587168,  0.48734652,  0.70882136,  0.93029621,  1.15177105,
#          1.37324589,  1.59472073,  1.81619557,  2.03767041,  2.25914525,
#          2.4806201 ,  2.70209494,  2.92356978,  3.14504462,  3.36651946,
#          3.5879943 ]),
#  <BarContainer object of 30 artists>)

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /Users/marctub/Library/Python/3.9/lib/python/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/marctub/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/marctub/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/marctub/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/marctub/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.6.0)

# %%
import sys
print(sys.executable)
# Out:
# /Users/marctub/Documents/AI-engineering/ai-engineering-from-scratch/.venv/bin/python3

# %%
# !uv pip install scikit-learn
# Out:
# Using Python 3.12.13 environment at: /Users/marctub/Documents/AI-engineering/ai-engineering-from-scratch/.venv
# Resolved 6 packages in 215ms
# Prepared 5 packages in 529ms
# Installed 5 packages in 12ms
#  + joblib==1.5.3
#  + narwhals==2.24.0
#  + scikit-learn==1.9.0
#  + scipy==1.18.0
#  + threadpoolctl==3.6.0

# %%
# %env
# Out:
# {'TERM_PROGRAM': 'Apple_Terminal',
#  'SHELL': '/bin/zsh',
#  'TERM': 'xterm-color',
#  'TMPDIR': '/var/folders/1q/mk1fbmc12412w_0rqx4qtlym0000gn/T/',
#  'TERM_PROGRAM_VERSION': '470.2',
#  'TERM_SESSION_ID': '9944754E-CDE0-45B0-AACC-1A972336142A',
#  'USER': 'marctub',
#  'SSH_AUTH_SOCK': '/var/run/com.apple.launchd.7zDCuPe0R0/Listeners',
#  'PATH': '/Users/marctub/Documents/AI-engineering/ai-engineering-from-scratch/.venv/bin:/Users/marctub/.juliaup/bin:/Users/marctub/.local/state/fnm_multishells/5066_1784167943857/bin:/Users/marctub/.local/bin:/Users/marctub/Library/Python/3.9/bin:/Users/marctub/Library/Python/3.9/bin:/Users/marctub/.nvm/versions/node/v24.16.0/bin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/pkg/env/global/bin:/Users/marctub/.cargo/bin',
#  '__CFBundleIdentifier': 'com.apple.Terminal',
#  'PWD': '/Users/marctub/Documents/AI-engineering/practice-coding',
#  'XPC_FLAGS': '0x0',
#  'XPC_SERVICE_NAME': '0',
#  'SHLVL': '1',
#  'HOME': '/Users/marctub',
#  'LOGNAME': 'marctub',
#  'OSLogRateLimit': '64',
#  'COLORTERM': 'truecolor',
#  'OLDPWD': '/Users/marctub/Documents/AI-engineering/ai-engineering-from-scratch',
#  'HOMEBREW_PREFIX': '/opt/homebrew',
#  'HOMEBREW_CELLAR': '/opt/homebrew/Cellar',
#  'HOMEBREW_REPOSITORY': '/opt/homebrew',
#  'FPATH': '/opt/homebrew/share/zsh/site-functions:/usr/local/share/zsh/site-functions:/usr/share/zsh/site-functions:/usr/share/zsh/5.9/functions',
#  'INFOPATH': '/opt/homebrew/share/info:',
#  'NVM_DIR': '/Users/marctub/.nvm',
#  'NVM_CD_FLAGS': '-q',
#  'NVM_BIN': '/Users/marctub/.nvm/versions/node/v24.16.0/bin',
#  'NVM_INC': '/Users/marctub/.nvm/versions/node/v24.16.0/include/node',
#  'FNM_MULTISHELL_PATH': '/Users/marctub/.local/state/fnm_multishells/5066_1784167943857',
#  'FNM_VERSION_FILE_STRATEGY': 'local',
#  'FNM_DIR': '/Users/marctub/.local/share/fnm',
#  'FNM_LOGLEVEL': 'info',
#  'FNM_NODE_DIST_MIRROR': 'https://nodejs.org/dist',
#  'FNM_COREPACK_ENABLED': 'false',
#  'FNM_RESOLVE_ENGINES': 'true',
#  'FNM_ARCH': 'arm64',
#  'VIRTUAL_ENV': '/Users/marctub/Documents/AI-engineering/ai-engineering-from-scratch/.venv',
#  'VIRTUAL_ENV_PROMPT': 'ai-engineering-from-scratch',
#  'PS1': '(ai-engineering-from-scratch) %n@%m %1~ %# ',
#  'LANG': 'zh_CN.UTF-8',
#  '_': '/Users/marctub/Documents/AI-engineering/ai-engineering-from-scratch/.venv/bin/jupyter',
#  '__CF_USER_TEXT_ENCODING': '0x1F5:0x19:0x34',
#  'JPY_SESSION_NAME': '/Users/marctub/Documents/AI-engineering/practice-coding/Untitled1.ipynb',
#  'JPY_PARENT_PID': '5125',
#  'PYDEVD_USE_FRAME_EVAL': 'NO',
#  'CLICOLOR': '1',
#  'FORCE_COLOR': '1',
#  'CLICOLOR_FORCE': '1',
#  'PAGER': 'cat',
#  'GIT_PAGER': 'cat',
#  'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})
df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
# !uv pip install pandas
# Out:
# Using Python 3.12.13 environment at: /Users/marctub/Documents/AI-engineering/ai-engineering-from-scratch/.venv
# Resolved 4 packages in 171ms
# Prepared 1 package in 259ms
# Installed 1 package in 7ms
#  + pandas==3.0.3

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Inline Plot")
plt.show()

# %%
import random
# %timeit [random.gauss(0,1) for _ in range(100000)]
# Out:
# 12 ms ± 44.4 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
import numpy as np
# %timeit np.random.randn(100000)
# Out:
# 780 μs ± 3.02 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
